# %%
#Ejer 01: Crear en el PC un fichero con un contenido de Loren Ipsum y subirlo
import requests
from io import BytesIO
from PIL import Image
url = 'https://github.com/nma-rincon/salvador/blob/main/ejercicio1/ejer1.png?raw=true'
page = requests.get(url)
Image.open(BytesIO(page.content))
#SI ejecutas el codigo te da una imagen
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1152x671>

# %%
#Ejer 02: Descargar el fichero subido en el apartado anterior (Ejer01)
from google.colab import files
#ESO ES PARA CREAR EL TXT POR COMANDSO
with open('lore.txt', 'w') as f:
  f.write('some content')

from google.colab import files
#En mi caso llame al archivo LORE, asi que descargo ese.
files.download('lore.txt')

# %%
#Ejer 03: Crear en drive un directorio llamado GoogleColab_test_Ejer_24_25 y dentro de ella un fichero con un contenido
#      de Loren Ipsum. Consultar/verificar su creación en Google Drive y en el navegador de Google Colab

from google.colab import drive
drive.flush_and_unmount
#Monto el drive
drive.mount('/content/drive', force_remount=True)
# Creo la carpeta, dara error si esta creada
# !mkdir '/content/drive/My Drive/GoogleColab_test_Ejer_24_25'

from google.colab import files

with open('/content/drive/My Drive/GoogleColab_test_Ejer_24_25/Loren Ipsum.txt', 'w') as f:
  f.write('Loren Ipsum')

#Esta parte es solo para el colab muestre una foto
import requests
from io import BytesIO
from PIL import Image
url = 'https://github.com/nma-rincon/salvador/blob/main/ejercicio1/ejer3.png?raw=true'
page = requests.get(url)
Image.open(BytesIO(page.content))
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/GoogleColab_test_Ejer_24_25’: File exists
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=982x485>

# %%
#Ejer 04: En la carpeta creada en el ejercicio anterior (GoogleColab_test_Ejer_24_25), crear un fichero cuyo nombre sean tu nombre y apellidos,
# en su contenido incluir un texto LorenIpsum distinto al utilizado en el punto anterior (de 50 palabras y añadir tu nombre al principio)
# y al terminar mostrar su contenido.
# Similar al ejemplo. Validar su existencia consultando Gdrive.ListFile  y el explorador de archivos de GoogleColab en este notebook


from google.colab import drive
drive.flush_and_unmount
drive.mount('/content/drive', force_remount=True)
from google.colab import files

#ESCRIBO 50 PALABRAS CON MI NOMBRE
with open('/content/drive/My Drive/GoogleColab_test_Ejer_24_25/NESTORMARTINDELAFUENTEAROCHA.txt', 'w') as f:

  f.write(' NESTOR MARTIN DE LA FUENTE AROCHA ')
  for i in range(50):
    f.write(' Lore Impsum ')

#LEO 50 PALABRAS CON MI NOMBRE
with open('/content/drive/My Drive/GoogleColab_test_Ejer_24_25/NESTORMARTINDELAFUENTEAROCHA.txt', 'r') as f:
  FileContent = f.read()
  print(FileContent)

#IMAGEN
import requests
from io import BytesIO
from PIL import Image
url = 'https://github.com/nma-rincon/salvador/blob/main/ejercicio1/ejer4.png?raw=true'
page = requests.get(url)
Image.open(BytesIO(page.content))
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/GoogleColab_test_Ejer_24_25’: File exists
#  NESTOR MARTIN DE LA FUENTE AROCHA  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=275x250>

# %%
#Ejer 05: Mostrar una lista de los ficheros que existen en el directorio GoogleColab_test_Ejer_24_25

# Authenticate and create the PyDrive client.
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

from google.colab import drive
drive.mount('/content/drive')


auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()

for file1 in file_list:
    print('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# title: BIGDATA2425, id: 1VArBXPQoMKGTlQ2BAGqvUw4LfiFc_pdd
# title: FINALASIR2, id: 1g9JtZtO-uiOTzqp7MRHTyq10KxROiJrL
# title: 1ASIR, id: 1PYrW7cvFWV39SlROoTa8sxap4iuFs1Sa
# title: GoogleColab_test_Ejer_24_25, id: 1-iuIeQlch6QoIMhvDR4KB2ojysctbokp
# title: .ipynb_checkpoints, id: 1-6_LSRw-UrCUJ5Px69dEra7OgV5-ami7
# title: Colab Notebooks, id: 1ACtzcsuYekpUTDgyRg2dqQOgfEJP-DSN
# title: Titula.pdf, id: 1z6vRtg-OXrkwlqdrWHKkJJN2i9FtcYWC

# %%
# Ejer 06: Haciendo uso de la api (ejemplo anterior) descargar/mostrar el contenido del fichero que creaste con contenido LorenIpsum
#       en la carpeta GoogleColab_test_Ejer y con el nombre tuyo.

from google.colab import drive
drive.mount('/content/drive')
from googleapiclient.http import MediaFileUpload
from google.colab import auth
auth.authenticate_user()
from googleapiclient.discovery import build
drive_service = build('drive', 'v3')
from googleapiclient.http import MediaFileUpload

file_metadata = {
  'name': 'Sample file 24_25',
  'mimeType': 'text/plain'
}
media = MediaFileUpload('/content/drive/MyDrive/GoogleColab_test_Ejer_24_25/NESTORMARTINDELAFUENTEAROCHA.txt',mimetype='text/plain',resumable=True)

created = drive_service.files().create(body=file_metadata,media_body=media,fields='id').execute()
print('File ID: {}'.format(created.get('id')))

created = drive_service.files().create(body=file_metadata,media_body=media,fields='id').execute()
file_id = created.get('id')

#Mostrarlo
import io
from googleapiclient.http import MediaIoBaseDownload

request = drive_service.files().get_media(fileId=file_id)
downloaded = io.BytesIO()
downloader = MediaIoBaseDownload(downloaded, request)
done = False
while done is False:
  # _ is a placeholder for a progress object that we ignore.
  # (Our file is small, so we skip reporting progress.)
  _, done = downloader.next_chunk()

downloaded.seek(0)
print('Downloaded file contents are: {}'.format(downloaded.read()))
# Out:
# Mounted at /content/drive
# File ID: 1fkw0Ob7XKg0aEBN9nD88Qx7YX9fNSOUO
# Downloaded file contents are: b' NESTOR MARTIN DE LA FUENTE AROCHA  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum  Lore Impsum '

# %%
# Ejer 07: Subir a un repositorio de GitHub una hoja de cálculo en formato csv y realizar la importanción a un dataframe,
# utilizando como separador de campos un "punto y coma" ;
import pandas as pd

# URL del archivo CSV en GitHub (reemplaza con tu información)
url = 'https://raw.githubusercontent.com/nma-rincon/salvador/refs/heads/main/ejercicio1/dataset.csv'

# Importar el CSV utilizando punto y coma como separador
df = pd.read_csv(url)

# Mostrar el DataFrame
df
# Out:
#                                      Sentence;Sentiment
# 0     The GeoSolutions technology will leverage Bene...
# 1     $ESI on lows; down $1.50 to $2.50 BK a real po...
# 2     For the last quarter of 2010 ; Componenta 's n...
# 3     According to the Finnish-Russian Chamber of Co...
# 4     The Swedish buyout firm has sold its remaining...
# ...                                                 ...
# 5837  RISING costs have forced packaging producer Hu...
# 5838  Nordic Walking was first used as a summer trai...
# 5839  According shipping company Viking Line ; the E...
# 5840  In the building and home improvement trade ; s...
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...
#
# [5842 rows x 1 columns]
